# %%
import pandas as pd

with open('all_week_end_nov_4.csv', 'r') as file:
    last_week = pd.read_csv(file)
with open('all_week_aug_13_20.csv', 'r') as file2:
    week_old = pd.read_csv(file2)

week_old.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2018-08-21T02:23:41.411Z  63.099600 -144.310000   4.20  1.60      ml   NaN
# 1  2018-08-21T02:18:28.720Z  33.503833 -116.794000   2.91  0.36      ml  14.0
# 2  2018-08-21T02:13:08.870Z  33.502167 -116.793833   2.72  0.70      ml  22.0
# 3  2018-08-21T02:12:01.910Z  33.499000 -116.784000   2.77  0.50      ml  18.0
# 4  2018-08-21T02:06:18.720Z  33.252333 -116.409667   3.83  0.75      ml  12.0
#
#     gap     dmin   rms    ...                      updated  \
# 0   NaN      NaN  0.48    ...     2018-08-21T02:26:33.886Z
# 1  74.0  0.01003  0.09    ...     2018-08-21T02:21:57.452Z
# 2  67.0  0.01154  0.14    ...     2018-08-21T02:16:53.037Z
# 3  58.0  0.01909  0.12    ...     2018-08-21T02:15:42.724Z
# 4  80.0  0.01702  0.22    ...     2018-08-21T02:09:45.924Z
#
#                           place        type horizontalError depthError  \
# ...

# %%
df1 = pd.DataFrame(last_week)
df2 = pd.DataFrame(week_old)

comb_df = df1.append(ignore_index=True, other=df2)

locations = comb_df.iloc[:,1:3].values.tolist()
locations
# Out:
# [[33.2873333, -115.8755],
#  [55.8943, -149.9913],
#  [33.512666700000004, -116.79816670000001],
#  [33.8945, -117.02033329999999],
#  [33.51, -116.8],
#  [60.2456, -140.6343],
#  [64.8912, -148.8398],
#  [33.5945, -116.82600000000001],
#  [18.0083, -66.528],
#  [33.9866667, -116.93233329999998],
#  [33.497, -116.79316670000001],
#  [44.8096667, -111.11233329999999],
#  [37.6231651, -118.91133119999999],
#  [61.2725, -150.2197],
#  [35.3138333, -118.51983329999999],
#  [65.9461, -147.4061],
#  [61.0746, -151.4305],
#  [38.799167600000004, -122.77999879999999],
#  [33.6026667, -116.67783329999999],
#  [33.2476667, -116.6758333],
#  [35.3133333, -118.51799999999999],
#  [36.6834984, -121.30333710000001],
#  [-24.195, -67.3297],
#  [33.5472, 89.3869],
#  [62.4344, -152.3492],
#  [63.5893, -150.7414],
#  [33.489000000000004, -116.80283329999999],
#  [58.7306, -153.7275],
#  [33.5105, -116.7975],
#  [60.9086, -152.5063],
#  [-18.804000000000002, -177.447],
# ...

# %%
import arcgis

from arcgis.features import SpatialDataFrame

sdf = SpatialDataFrame(comb_df.set_geometry([arcgis.geometry.Geometry({'x':r[1], 'y':r[0],'spatialReference':{'wkid':4326}}) for r in locations]))
sdf.reset_index(inplace=True, drop=True)
sdf.to_featureclass(out_location='D:/GIS 5091/Week 9/week_9.gdb', out_name='EQs')
# Out:
# 'D:\\GIS 5091\\Week 9\\week_9.gdb\\EQs'
